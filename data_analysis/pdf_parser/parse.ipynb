# %%
import tabula

# %%
# Read pdf into list of DataFrame
pdf = tabula.read_pdf("trans.pdf", encoding='gbk', pages='all')
type(pdf)
# Out:
# list

# %%
import pdfplumber

path = 'trans.pdf'
pdf = pdfplumber.open(path)

for page in pdf.pages:
    # 获取当前页面的全部文本信息，包括表格中的文字
    print(page.extract_text())                        

#     for table in page.extract_tables():
#         print(table)
#         for row in table:
#             print(row)
#         print('---------- 分割线 ----------')

pdf.close()
# Out:
# 收费公路通行费电子票据汇总单
# （按行程索引）
# 汇总单号: 5020200800183213 开票申请日期: 2020-08-24
# 车牌号码 渝DV3012 交易金额 ￥13,919.47 购买方名称 重庆索尚商贸有限公司
# 行程数量 38 票据数量 5 纳税人识别号 9150024034591465XK
# 行程信息 票据信息
# 行程 通行日期 票据 金额
# 出入口信息 交易金额 拆分金额 票据代码 票据号码 税率 税额
# 序号 起止 序号 （含税）
# 481.78 1 050001800112 17925107 8058.23 不征税 -
# 鄂·湖北巴东
# 北站
# 113.62 2 042001700112 32098619 1818.00 3% 52.95
# 20200801
# 1 至 777.09
# 20200801
# 52.01 3 042001700112 57240191 832.16 3% 24.24
# 鄂·湖北枝城
# 站
# 129.68 4 042001700112 28772361 2074.88 3% 60.43
# 同1号
# 78.03 050001800112 17925107 - - -
# 发票
# 鄂·湖北枝城
# 站 同2号
# 113.63 042001700112 32098619 - - -
# 20200801 发票
# 2 至 373.35
# 20200801 同3号
# 52.01 042001700112 57240191 - - -
# 鄂·湖北宜昌 发票
# 北站
# 同4号
# 129.68 042001700112 28772361 - - -
# 发票
# 鄂·湖北雾渡
# 河站
# 20200801 同1号
# 3 至 282.15 282.15 050001800112 17925107 - - -
# 20200801 发票
# 鄂·湖北巴东
# 北站
# 鄂·湖北沿渡 同1号
# 39.90 050001800112 17925107 - - -
# 河站 发票
# 20200801
# 4 至 127.30
# 20200801
# 87.40 5 050001800112 01279659 1136.20 3% 33.09
# 渝·重庆巫山
# 站
# 渝·重庆巫山 同1号
# 39.90 050001800112 17925107 - - -
# 站 发票
# 20200802
# 5 至 127.30
# 20200802 同5号
# 87.40 050001800112 01279659 - - -
# 鄂·湖北沿渡 发票
# 河站
# 同1号
# 481.78 050001800112 17925107 - - -
# 发票
# 鄂·湖北巴东
# 北站 同2号
# 113.62 042001700112 32098619 - - -
# 20200808 发票
# 6 至 777.09
# 20200808 同3号
# 52.01 042001700112 57240191 - - -
# 鄂·湖北枝城 发票
# 站
# 同4号
# 129.68 042001700112 28772361 - - -
# 发票
# 同1号
# 78.03 050001800112 17925107 - - -
# 发票
# 鄂·湖北枝城
# 站 同2号
# 113.63 042001700112 32098619 - - -
# 20200808 发票
# 7 至 373.35
# 20200808 同3号
# 52.01 042001700112 57240191 - - -
# 鄂·湖北宜昌 发票
# 北站
# 同4号
# 129.68 042001700112 28772361 - - -
# 发票
# 鄂·湖北宜昌
# 北站
# 20200808 同1号
# 8 至 403.65 403.65 050001800112 17925107 - - -
# 20200809 发票
# 鄂·湖北巴东
# 北站
# 鄂·湖北沿渡 同1号
# 39.90 050001800112 17925107 - - -
# 河站 发票
# 20200809
# 9 至 127.30
# 20200809 同5号
# 87.40 050001800112 01279659 - - -
# 渝·重庆巫山 发票
# 站
# 渝·重庆巫山 同1号
# 39.90 050001800112 17925107 - - -
# 站 发票
# 20200809 至
# 10 127.30
# 20200809 同5号
# 鄂·湖北沿渡 87.40 发票 050001800112 01279659 - - -
# 河站
# 同1号
# 481.78 050001800112 17925107 - - -
# 发票
# 鄂·湖北巴东
# 北站 同2号
# 113.62 042001700112 32098619 - - -
# 20200809 发票
# 11 至 777.09
# 20200809 同3号
# 52.01 042001700112 57240191 - - -
# 鄂·湖北枝城 发票
# 站
# 同4号
# 129.68 042001700112 28772361 - - -
# 发票
# 同1号
# 78.03 050001800112 17925107 - - -
# 发票
# 鄂·湖北枝城
# 站 同2号
# 113.63 042001700112 32098619 - - -
# 20200809 发票
# 12 至 373.35
# 20200809 同3号
# 52.01 042001700112 57240191 - - -
# 鄂·湖北宜昌 发票
# 北站
# 同4号
# 129.68 042001700112 28772361 - - -
# 发票
# 鄂·湖北宜昌
# 北站
# 20200809 同1号
# 13 至 403.65 403.65 050001800112 17925107 - - -
# 20200810 发票
# 鄂·湖北巴东
# 北站
# 鄂·湖北沿渡 同1号
# 39.90 050001800112 17925107 - - -
# 河站 发票
# 20200810
# 14 至 127.30
# 20200810 同5号
# 87.40 050001800112 01279659 - - -
# 渝·重庆巫山 发票
# 站
# 渝·重庆巫山 同1号
# 39.90 050001800112 17925107 - - -
# 站 发票
# 20200810
# 15 至 127.30
# 20200810 同5号
# 87.40 050001800112 01279659 - - -
# 鄂·湖北沿渡 发票
# 河站
# 同1号
# 481.78 050001800112 17925107 - - -
# 发票
# 鄂·湖北巴东
# 北站 同2号
# 113.62 042001700112 32098619 - - -
# 20200813 发票
# 16 至 777.09
# 20200813 同3号
# 52.01 042001700112 57240191 - - -
# 鄂·湖北枝城 发票
# 站
# 同4号
# 129.68 042001700112 28772361 - - -
# 发票
# 同1号
# 78.03 050001800112 17925107 - - -
# 发票
# 鄂·湖北枝城
# 站 同2号
# 113.63 042001700112 32098619 - - -
# 20200813 发票
# 17 至 373.35
# 20200813 同3号
# 52.01 042001700112 57240191 - - -
# 鄂·湖北宜昌 发票
# 北站
# 同4号
# 129.68 042001700112 28772361 - - -
# 发票
# 鄂·湖北宜昌
# 北站
# 20200813 同1号
# 18 至 403.65 403.65 050001800112 17925107 - - -
# 20200813 发票
# 鄂·湖北巴东
# 北站
# 鄂·湖北沿渡 同1号
# 39.90 050001800112 17925107 - - -
# 河站 发票
# 20200813
# 19 至 127.30
# 20200813 同5号
# 87.40 050001800112 01279659 - - -
# 渝·重庆巫山 发票
# 站
# 渝·重庆巫山 同1号
# 39.90 050001800112 17925107 - - -
# 站 发票
# 20200814
# 20 至 127.30
# 20200814 同5号
# 87.40 050001800112 01279659 - - -
# 鄂·湖北沿渡 发票
# 河站
# 同1号
# 481.78 050001800112 17925107 - - -
# 发票
# 鄂·湖北巴东
# 北站 同2号
# 113.62 042001700112 32098619 - - -
# 20200814 发票
# 21 至 777.09
# 20200814 同3号
# 52.01 042001700112 57240191 - - -
# 鄂·湖北枝城 发票
# 站
# 同4号
# 129.68 042001700112 28772361 - - -
# 发票
# 同1号
# 78.03 050001800112 17925107 - - -
# 发票
# 鄂·湖北枝城 113.63 同2号 042001700112 32098619 - - -
# 20200814
# 22 站 373.35 发票
# 20200814
# 至 52.01 同3号 042001700112 57240191 - - -
# 发票
# 鄂·湖北宜昌
# 同4号
# 北站 129.68 042001700112 28772361 - - -
# 发票
# 鄂·湖北宜昌
# 北站
# 20200814 同1号
# 23 至 403.65 403.65 050001800112 17925107 - - -
# 20200815 发票
# 鄂·湖北巴东
# 北站
# 鄂·湖北沿渡 同1号
# 39.90 050001800112 17925107 - - -
# 河站 发票
# 20200815
# 24 至 127.30
# 20200815 同5号
# 87.40 050001800112 01279659 - - -
# 渝·重庆巫山 发票
# 站
# 渝·重庆巫山 同1号
# 39.90 050001800112 17925107 - - -
# 站 发票
# 20200815
# 25 至 127.30
# 20200815 同5号
# 87.40 050001800112 01279659 - - -
# 鄂·湖北沿渡 发票
# 河站
# 同1号
# 481.78 050001800112 17925107 - - -
# 发票
# 鄂·湖北巴东
# 北站 同2号
# 113.62 042001700112 32098619 - - -
# 20200815 发票
# 26 至 777.09
# 20200815 同3号
# 52.01 042001700112 57240191 - - -
# 鄂·湖北枝城 发票
# 站
# 同4号
# 129.68 042001700112 28772361 - - -
# 发票
# 同1号
# 78.03 050001800112 17925107 - - -
# 发票
# 鄂·湖北枝城
# 站 同2号
# 113.63 042001700112 32098619 - - -
# 20200815 发票
# 27 至 373.35
# 20200815 同3号
# 52.01 042001700112 57240191 - - -
# 鄂·湖北宜昌 发票
# 北站
# 同4号
# 129.68 042001700112 28772361 - - -
# 发票
# 鄂·湖北宜昌
# 北站
# 20200815 同1号
# 28 至 403.65 403.65 050001800112 17925107 - - -
# 20200816 发票
# 鄂·湖北巴东
# 北站
# 渝·重庆巫山 同1号
# 39.90 050001800112 17925107 - - -
# 站 发票
# 20200816
# 29 至 127.30
# 20200816 同5号
# 87.40 050001800112 01279659 - - -
# 鄂·湖北沿渡 发票
# 河站
# 同1号
# 481.78 050001800112 17925107 - - -
# 发票
# 鄂·湖北巴东
# 北站 同2号
# 113.62 042001700112 32098619 - - -
# 20200816 发票
# 30 至 777.09
# 20200816 同3号
# 52.01 042001700112 57240191 - - -
# 鄂·湖北枝城 发票
# 站
# 同4号
# 129.68 042001700112 28772361 - - -
# 发票
# 同1号
# 78.03 050001800112 17925107 - - -
# 发票
# 鄂·湖北枝城
# 站 同2号
# 113.63 042001700112 32098619 - - -
# 20200816 发票
# 31 至 373.35
# 20200817 同3号
# 52.01 042001700112 57240191 - - -
# 鄂·湖北宜昌 发票
# 北站
# 同4号
# 129.68 042001700112 28772361 - - -
# 发票
# 鄂·湖北宜昌
# 北站
# 20200817 同1号
# 32 至 403.65 403.65 050001800112 17925107 - - -
# 20200817 发票
# 鄂·湖北巴东
# 北站
# 渝·重庆巫山 同1号
# 39.90 050001800112 17925107 - - -
# 站 发票
# 20200817
# 33 至 127.30
# 20200817 同5号
# 87.40 050001800112 01279659 - - -
# 鄂·湖北沿渡 发票
# 河站
# 481.78 同1号 050001800112 17925107 - - -
# 鄂·湖北巴东
# 发票
# 北站
# 20200817 同2号
# 34 至 777.09 113.62 042001700112 32098619 - - -
# 20200817 发票
# 鄂·湖北枝城 同3号
# 52.01 042001700112 57240191 - - -
# 站 发票
# 同4号
# 129.68 042001700112 28772361 - - -
# 发票
# 同1号
# 78.03 050001800112 17925107 - - -
# 发票
# 鄂·湖北枝城
# 站 同2号
# 113.63 042001700112 32098619 - - -
# 20200817 发票
# 35 至 373.35
# 20200818 同3号
# 52.01 042001700112 57240191 - - -
# 鄂·湖北宜昌 发票
# 北站
# 同4号
# 129.68 042001700112 28772361 - - -
# 发票
# 鄂·湖北宜昌
# 北站
# 20200818 同1号
# 36 至 242.00 242.00 050001800112 17925107 - - -
# 20200818 发票
# 鄂·湖北高岚
# 站
# 鄂·湖北兴山
# 站
# 20200818 同1号
# 37 至 115.00 115.00 050001800112 17925107 - - -
# 20200818 发票
# 鄂·湖北巴东
# 北站
# 渝·重庆巫山 同1号
# 39.90 050001800112 17925107 - - -
# 站 发票
# 20200818
# 38 至 127.30
# 20200818 同5号
# 87.40 050001800112 01279659 - - -
# 鄂·湖北沿渡 发票
# 河站
# 共38段行程 ￥13,919.47 共5张票据 ￥13,919.47 ￥170.71
# 价税合计（大写） U壹万叁仟玖佰壹拾玖元肆角柒分 （小写） ￥13,919.47
# 备注：
# 通行费电子票据服务平台网站（https://www.txffp.com）或票根APP
# 查验通行费财政电子票据信息请登录全国财政电子票据查验平台（http://pjcy.mof.gov.cn）
# 查验通行费电子发票信息请登录全国增值税发票查验平台（https://inv-veri.chinatax.gov.cn）
